# %% [markdown]
# ### Getting the data
#
# ##### Please look at the information in the `get_data.ipynb` notebook. You have to end up with `swift.dkrz.de` folder located somwere in your system. All data used in this examples are located in this folder.

# %%
import sys
sys.path.append("../")

import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from matplotlib.colors import LinearSegmentedColormap
import numpy as np
# %matplotlib notebook
# %matplotlib inline
from matplotlib import cm
from netCDF4 import Dataset, MFDataset
#import cmocean as ocm
# %load_ext autoreload
# %autoreload 2
import pyfesom as pf
# %aimport pyfesom
import matplotlib
matplotlib.rcParams.update({'font.size': 18})
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#basedir = '/mnt/lustre01/work/ab0995/a270088/DATA/swift.dkrz.de/'
basedir = '/work/ollie/orichter/MisomipPlus/'
meshpath  = basedir+'fesommesh/RG47911/2059/'
mesh = pf.fesom_mesh(meshpath, abg=[0,0,0])
lon_start = min(mesh.x2)
lat_start = np.mean(mesh.y2)
lon_end   = max(mesh.x2)
lat_end   = np.mean(mesh.y2)
#pf.plot_transect_map(lon_star
fl = Dataset(basedir+'fesomdata/RG47911/RG47911.2059.oce.nc')
fl.variables.keys()
# Out:
# Load 2d part of the grid in 0 second(s)
# correct for cavity
# Load 3d part of the grid in 0 seconds
# [u'time', u'ssh', u'u', u'v', u'w', u'wpot', u'temp', u'salt']

# %%
# %matplotlib inline
years = np.arange(1000,1095)
for year in years:
    year_out = str(year-1000).zfill(3)
    year = str(year)
    print('processing year '+year_out)
    meshpath  = basedir+'fesommesh/iceOceanG/'+year+'/'
    fl = Dataset(basedir+'fesomdata/iceOceanG/arch/iceOceanG.'+year+'.oce.nc')
    mesh = pf.fesom_mesh(meshpath, abg=[0,0,0])
    #pf.plot_transect_map(lon_star
    #fl = Dataset(basedir+'fesom_data/RG47911.2026.oce.nc')
    npoints = 1000
    lon_start = min(mesh.x2)
    lat_start = np.mean(mesh.y2)
    lon_end   = max(mesh.x2)
    lat_end   = np.mean(mesh.y2)
    data = np.mean(fl.variables['temp'][:,:],0)
    fig, ax = plt.subplots(1,1, figsize=(8,6))
    image = pf.plot_transect(data, mesh, 
                             lon_start,
                             lat_start,
                             lon_end,
                             lat_end,
                             npoints=npoints,
                             #levels = np.round(np.linspace(-1.9, 1, 42),2),
                             #levels = np.linspace(min(data),max(data)),
                             levels = np.linspace(-1.9,1.0),
                             cmap=cm.Spectral_r,
                             #cmap=cm.bwr,
                             maxdepth =6000,
                             title = 'year: '+year_out,
                             ncols=1,
                             figsize=(5,10),
                            ax = ax
                            )
    cb = fig.colorbar(image, orientation='horizontal', ax=ax, pad=0.13)
    cb.set_label('Potential Temperature in degC')
    plt.savefig("/work/ollie/orichter/MisomipPlus/reports/figures/iceOceanG_temp_"+year_out+".png")
    plt.show()
    plt.close()
# Out:
# processing year 000
# Load 2d part of the grid in 0 second(s)
# correct for cavity
# Load 3d part of the grid in 0 seconds
# processing year 001
# Load 2d part of the grid in 0 second(s)
# correct for cavity
# Load 3d part of the grid in 0 seconds
# processing year 002
# Load 2d part of the grid in 0 second(s)
# correct for cavity
# Load 3d part of the grid in 0 seconds
# processing year 003
# Load 2d part of the grid in 0 second(s)
# correct for cavity
# Load 3d part of the grid in 0 seconds
# processing year 004
# Load 2d part of the grid in 0 second(s)
# correct for cavity
# Load 3d part of the grid in 0 seconds
# processing year 005
# Load 2d part of the grid in 0 second(s)
# correct for cavity
# Load 3d part of the grid in 0 seconds
# processing year 006
# Load 2d part of the grid in 0 second(s)
# correct for cavity
# Load 3d part of the grid in 0 seconds
# processing year 007
# Load 2d part of the grid in 0 second(s)
# correct for cavity
# Load 3d part of the grid in 0 seconds
# ...

# %%
basedir = '/work/ollie/orichter/MisomipPlus/'
meshpath  = basedir+'fesommesh/iceOceanC/1006'

mesh = pf.fesom_mesh(meshpath, abg=[0,0,0]) ## for melt rate we need to deactivate cavity
fl = Dataset('/work/ollie/orichter/MisomipPlus/fesomdata/iceOceanC/arch/iceOceanC.1006.oce.nc')

#meshpath_z = '/work/ollie/orichter/mesh/oce0_z'
#mesh = pf.fesom_mesh(meshpath_z, abg=[0,0,0]) ## for melt rate we need to deactivate cavity
#fl = Dataset('/work/ollie/orichter/data/oce0com_z_0.80/RG47911.2024.oce.nc')
npoints = 1000
lon_start = mesh.x2.min()
lat_start = np.mean(mesh.y2)
lon_end   = mesh.x2.max()
lat_end   = np.mean(mesh.y2)
#data = np.mean(fl.variables['Kv'][4,:],0)
data = fl.variables['temp'][11,:]
#salt = fl.variables['salt'][2,:]
#ρ = ρ ref [1 − α lin (T − T ref ) + β lin (S − S ref )]
#data = 1027.51*(1-3.733e-5*(temp+1)+7.843e-4*(salt-34.2))
fig, ax = plt.subplots(1,1, figsize=(12,8))
image = pf.plot_transect(data, mesh, 
                         lon_start,
                         lat_start,
                         lon_end,
                         lat_end,
                         npoints=npoints,
                         #levels = np.round(np.linspace(33, 35, 1),2),
                         levels = np.linspace(-2.4,1),
                         #levels = np.linspace(-2,1),
                         cmap=cm.Spectral_r,
                         #cmap=cm.bwr,
                         maxdepth =1200,
                         title = 'monthly mean Potential Temperature at centerline; year: 6 month: 12',
                         ncols=1,
                         figsize=(5,10),
                        ax = ax
                        )
cb = fig.colorbar(image, orientation='horizontal', ax=ax, pad=0.13)
cb.set_label('Temperature in degC')
# Out:
# Load 2d part of the grid in 0 second(s)
# correct for cavity
# Load 3d part of the grid in 0 seconds

# %%
for month in [4,]
# Out:
# <type 'netCDF4._netCDF4.Variable'>
# float32 Kv(T, nodes_3d)
#     description: Instantaneous vertical diffusivity
#     units: m^2/s
# unlimited dimensions: T
# current shape = (13, 162935)
# filling off

# %% [markdown]
# First, as usuall load the mesh:

# %%
# %matplotlib notebook
meshpath  = basedir+'fesommesh/RG47911/2059/'
fl = Dataset(basedir+'fesomdata/RG47911/RG47911.2059.oce.nc')
#meshpath  = basedir+'fesom_mesh/010'
mesh = pf.fesom_mesh(meshpath, abg=[0,0,0])
#pf.plot_transect_map(lon_star
#fl = Dataset(basedir+'fesom_data/RG47911.2026.oce.nc')
npoints = 1000
lon_start = 3.9718
lat_start = 0.325
lon_end   = 3.9718+0.05
lat_end   = 0.325
data = fl.variables['temp'][-1,:]
fig, ax = plt.subplots(1,1, figsize=(10,8))
image = pf.plot_transect(data, mesh, 
                         lon_start,
                         lat_start,
                         lon_end,
                         lat_end,
                         npoints=npoints,
                         #levels = np.round(np.linspace(-2, 2, 42),2),
                         #levels = np.linspace(min(data),max(data)),
                         levels = np.linspace(-0.3,0.5),
                         cmap=cm.Spectral_r,
                         #cmap=cm.bwr,
                         maxdepth =1200,
                         title = 'Remapped temperature at centerline',
                         ncols=1,
                         figsize=(5,10),
                        ax = ax
                        )
cb = fig.colorbar(image, orientation='horizontal', ax=ax, pad=0.13)
cb.set_label('Potential Temperature in degC')
# Out:
# Load 2d part of the grid in 0 second(s)
# correct for cavity
# Load 3d part of the grid in 0 seconds
# <img src="data:image/png;base64,..." width="720">

# %%
meshpath  = basedir+'fesom_mesh/000/'
mesh = pf.fesom_mesh(meshpath, abg=[0,0,0])
#pf.plot_transect_map(lon_star
fl = Dataset(basedir+'fesom_data/old/RG47911.2026.oce.nc')
npoints = 1000
data = fl.variables['temp'][-1,:]
fig, ax = plt.subplots(1,1, figsize=(8,5))
image = pf.plot_transect(data, mesh, 
                         lon_start,
                         lat_start,
                         lon_end,
                         lat_end,
                         npoints=npoints,
                         #levels = np.round(np.linspace(-2, 2, 42),2),
                         levels = np.linspace(min(data),max(data)),
                         #levels = np.linspace(-0.02,0.02),
                         cmap=cm.Spectral_r,
                         #cmap=cm.bwr,
                         maxdepth =6000,
                         title = 'Temperature bevor remapping at centerline',
                         ncols=1,
                         figsize=(5,10),
                        ax = ax
                        )
cb = fig.colorbar(image, orientation='horizontal', ax=ax, pad=0.13)
cb.set_label('Potential Temperature in degC')
# Out:
# Load 2d part of the grid in 0 second(s)
# correct for cavity
# Load 3d part of the grid in 0 seconds
# <img src="data:image/png;base64,..." width="575.5555708025713">

# %%
#basedir = '/mnt/lustre01/work/ab0995/a270088/DATA/swift.dkrz.de/'
basedir = '/work/ollie/orichter/'
meshpath  = basedir+'mesh/oce0_sigma_grid/'
mesh = pf.fesom_mesh(meshpath, abg=[0,0,0], cavity='sigma')
lon_start = min(mesh.x2)
lat_start = np.mean(mesh.y2)
lon_end   = max(mesh.x2)
lat_end   = np.mean(mesh.y2)
fl = Dataset(basedir+'/data/warm_sigma/RG47911.2021.oce.nc')
fl['temp']
# Out:
# Load 2d part of the grid in 0 second(s)
# Load 3d part of the grid in 0 seconds
# <type 'netCDF4._netCDF4.Variable'>
# float64 temp(T, nodes_3d)
#     description: potential temperature
#     units: degC
# unlimited dimensions: T
# current shape = (5, 229326)
# filling off

# %%
#level_data, elem_no_nan = pf.get_data_sigma(mesh.,mesh,sigma=0)

# %%
mesh.shelf.shape
# Out:
# (6198,)

# %%
shelf_path = basedir+'mesh/oce0_z_grid/shelf.out'
import pandas as pd
df = pd.read_csv(shelf_path, delim_whitespace=True, skiprows=0, \
                                    names=['shelf'])
mesh.shelf = df.shelf.values
level_data, elem_no_nan = pf.get_data_sigma(mesh.shelf,mesh,sigma=0)
plt.figure(figsize=(9,7))
levels = np.linspace(level_data.min(),level_data.max(),10)
plt.tricontourf(mesh.x2, mesh.y2, elem_no_nan[::], level_data, levels = levels, cmap=cm.Spectral_r, extend='both')
cbar = plt.colorbar(orientation='horizontal', pad=0.03);
cbar.set_label("shelf draft in m")
plt.title('shelf draft interpolated')
plt.tight_layout()

# %%
import pandas as pd
shelf_path = basedir+'mesh/oce0_sigma_grid/shelf_2.out'
df = pd.read_csv(shelf_path, delim_whitespace=True, skiprows=0, \
                                    names=['shelf'])
mesh.shelf = df.shelf.values
level_data, elem_no_nan = pf.get_data_sigma(mesh.shelf,mesh,sigma=0)


plt.figure(figsize=(9,7))
levels = np.linspace(level_data.min(),level_data.max(),10)
plt.tricontourf(mesh.x2, mesh.y2, elem_no_nan[::], level_data, levels = levels, cmap=cm.Spectral_r, extend='both')
cbar = plt.colorbar(orientation='horizontal', pad=0.03);
cbar.set_label("Shelf draft in m")
plt.title('shelf draft smoothed using r1_crit = 6 and min_water_thickness = 200')
plt.tight_layout()

# %%
import pandas as pd
shelf_path = basedir+'mesh/oce0_sigma_grid/shelf.out'
df = pd.read_csv(shelf_path, delim_whitespace=True, skiprows=0, \
                                    names=['shelf'])
mesh.shelf = df.shelf.values
level_data, elem_no_nan = pf.get_data_sigma(mesh.shelf,mesh,sigma=0)


plt.figure(figsize=(9,7))
levels = np.linspace(level_data.min(),level_data.max(),10)
plt.tricontourf(mesh.x2, mesh.y2, elem_no_nan[::], level_data, levels = levels, cmap=cm.Spectral_r, extend='both')
cbar = plt.colorbar(orientation='horizontal', pad=0.03);
cbar.set_label("Shelf draft in m")
plt.title('shelf draft smoothed using r1_crit = 6 and min_water_thickness = 200')
plt.tight_layout()

# %%
import pandas as pd
shelf_path = basedir+'mesh/oce0_sigma_grid/shelf_2.out'
df = pd.read_csv(shelf_path, delim_whitespace=True, skiprows=0, \
                                    names=['shelf'])
mesh.shelf = df.shelf.values
level_data, elem_no_nan = pf.get_data_sigma(mesh.shelf,mesh,sigma=0)


plt.figure(figsize=(9,7))
levels = np.linspace(level_data.min(),level_data.max(),10)
plt.tricontourf(mesh.x2, mesh.y2, elem_no_nan[::], level_data, levels = levels, cmap=cm.Spectral_r, extend='both')
cbar = plt.colorbar(orientation='horizontal', pad=0.03);
cbar.set_label("Shelf draft in m")
plt.title('shelf draft smoothed using r1_crit = 6 and min_water_thickness = 200')
plt.tight_layout()

# %%
shelf_path = basedir+'mesh/oce0_sigma_grid/shelf_2.out'
df = pd.read_csv(shelf_path, delim_whitespace=True, skiprows=0, \
                                    names=['shelf'])
mesh.shelf = df.shelf.values
level_data, elem_no_nan = pf.get_data_sigma(mesh.shelf,mesh,sigma=0)


plt.figure(figsize=(9,7))
levels = np.linspace(level_data.min(),level_data.max(),10)
plt.tricontourf(mesh.x2, mesh.y2, elem_no_nan[::], level_data, levels = levels, cmap=cm.Spectral_r, extend='both')
cbar = plt.colorbar(orientation='horizontal', pad=0.03);
cbar.set_label("Shelf draft in m")
plt.title('shelf draft smoothed using r1_crit = 4 and min_water_thickness = 300')
plt.tight_layout()

# %%
shelf_path = basedir+'mesh/oce0_sigma_grid/shelf.out'
df = pd.read_csv(shelf_path, delim_whitespace=True, skiprows=0, \
                                    names=['shelf'])
mesh.shelf = df.shelf.values
level_data, elem_no_nan = pf.get_data_sigma(mesh.shelf,mesh,sigma=0)

level_data, elem_no_nan = pf.get_data_sigma(mesh.shelf,mesh,sigma=0)
plt.figure(figsize=(9,7))
levels = np.linspace(level_data.min(),level_data.max(),10)
plt.tricontourf(mesh.x2, mesh.y2, elem_no_nan[::], level_data, levels = levels, cmap=cm.Spectral_r, extend='both')
cbar = plt.colorbar(orientation='horizontal', pad=0.03);
cbar.set_label("Shelf draft in m")
plt.title('shelf draft smoothed using r1_crit = 4 and min_water_thickness = 200')
plt.tight_layout()

# %% [markdown]
# Decide start and end points of the transect and plot the map of your future transect. Use `%matplotlib notebook` if you whant to be able to zoom to the map. NOTE! you have to have cartopy installed to make the plotting work.

# %%
npoints = 1000
data = fl.variables['temp'][-1,:]
#fig, ax = plt.subplots(1,1, figsize=(15,7))
nodes,profile,dist = pf.plot_transect_sigma(data, mesh, 
                         lon_start,
                         lat_start,
                         lon_end,
                         lat_end,
                         npoints=npoints,
                         #levels = np.round(np.linspace(-2, 2, 42),2),
                         levels = np.linspace(min(data),max(data)),
                         #levels = np.linspace(-0.02,0.02),
                         cmap=cm.Spectral_r,
                         #cmap=cm.bwr,
                         maxdepth =6000,
                         title = 'Temperature for boundary restoring test (warm initial+cold forcing after 1 month)',
                         ncols=1,
                         figsize=(5,10),
                        ax = ax
                        )

# %%
basedir = '/work/ollie/orichter/'
meshpath  = basedir+'mesh/oce0_z_grid/'
mesh_z = pf.fesom_mesh(meshpath, abg=[0,0,0], cavity=True)
fl = Dataset(basedir+'/data/warm/RG47911.2021.oce.nc')
data_z = fl['temp'][-1,:]
# Out:
# Load 2d part of the grid in 0 second(s)
# correct for cavity
# Load 3d part of the grid in 0 seconds

# %%
meshpath = '/work/ollie/orichter/mesh/oce0_sigma_grid'
mesh_s = pf.fesom_mesh(meshpath, abg=[0,0,0],cavity='sigma')
fl = Dataset('/work/ollie/orichter/data/warm_sigma/RG47911.2021.oce.nc')
data_s = fl['temp'][-1,:]
# Out:
# Load 2d part of the grid in 0 second(s)
# Load 3d part of the grid in 0 seconds

# %%
data_sonz = pf.interp_sigma2z(mesh_s,data_s,mesh_z)

# %%
npoints = 1000
#data = fl.variables['temp'][-1,:]
data = data_sonz
fig, ax = plt.subplots(1,1, figsize=(15,7))
image = pf.plot_transect(data, mesh_z, 
                         lon_start,
                         lat_start,
                         lon_end,
                         lat_end,
                         npoints=npoints,
                         #levels = np.round(np.linspace(-2, 2, 42),2),
                         levels = np.linspace(min(data),max(data)),
                         #levels = np.linspace(-0.02,0.02),
                         cmap=cm.Spectral_r,
                         #cmap=cm.bwr,
                         maxdepth =6000,
                         title = 'Temperature for boundary restoring test (warm initial+cold forcing after 1 month)',
                         ncols=1,
                         figsize=(5,10),
                        ax = ax
                        )
cb = fig.colorbar(image, orientation='horizontal', ax=ax, pad=0.13)
cb.set_label('Potential Temperature in degC')

# %%
fl = Dataset('/work/ollie/orichter/data/warm_sigma/RG47911.2021.forcing.diag.nc')
fl.variables['wnet']
level_data, elem_no_nan = pf.get_data_sigma(fl.variables['wnet'][-1,:],mesh_s,0)
plt.figure(figsize=(9,7))
levels = np.linspace(level_data.min(),level_data.max(),10)
plt.tricontourf(mesh_s.x2, mesh_s.y2, elem_no_nan[::], level_data, levels = levels, cmap=cm.Spectral_r, extend='both')
cbar = plt.colorbar(orientation='horizontal', pad=0.03);
cbar.set_label("Shelf draft in m")
plt.title('shelf draft smoothed using r1_crit = 4 and min_water_thickness = 200')
plt.tight_layout()

# %%
meshpath = '/work/ollie/orichter/mesh/oce0_z_grid'
mesh = pf.fesom_mesh(meshpath, abg=[0,0,0],cavity=False)
fl = Dataset('/work/ollie/orichter/data/warm/RG47911.2021.forcing.diag.nc')
fl.variables['wnet']
level_data, elem_no_nan = pf.get_data(fl.variables['wnet'][-1,:],mesh,0)
plt.figure(figsize=(9,7))
levels = np.linspace(level_data.min(),level_data.max(),10)
plt.tricontourf(mesh.x2, mesh.y2, elem_no_nan[::], level_data, levels = levels, cmap=cm.Spectral_r, extend='both')
cbar = plt.colorbar(orientation='horizontal', pad=0.03);
cbar.set_label("Shelf draft in m")
plt.title('shelf draft smoothed using r1_crit = 4 and min_water_thickness = 200')
plt.tight_layout()
# Out:
# Load 2d part of the grid in 0 second(s)
# Load 3d part of the grid in 0 seconds
# For depth 0 model level -0.0 will be used

# %%
data_interp = np.ones_like(data_z)*-999
for i in np.arange(mesh_z.n2d):
    z0 = mesh_s.zcoord[mesh_s.n32[i]-1]
    data0 = data_s[mesh_s.n32[i]-1]
    tn = mesh_z.n32[i]>=0
    prof_intp = np.interp(mesh.zlevs[tn],z0,data0)
    data_interp[mesh_z.n32[i][tn]-1]=prof_intp

# %%
(data_interp==-999).any()
# Out:
# False

# %%
# Out:
# array([   1, 6199, 6200, 6201, 6202, 6203, -999, -999, -999, -999, -999,
#        -999, -999, -999, -999, -999, -999, -999, -999, -999, -999, -999,
#        -999, -999, -999, -999, -999, -999, -999, -999, -999, -999, -999,
#        -999, -999, -999, -999])

# %%
mesh_z.zlevs.shape
# Out:
# (37,)

# %%
tn.shape
# Out:
# (38,)

# %%
plt.plot(mesh.y2[np.unique(nodes)[sort1d]]-np.mean(mesh.y2))

# %%
plt.plot(z2d[0:50,0])

# %%
# %matplotlib notebook
fig = plt.figure(figsize=(12,4))
n = np.arange(mesh.n2d)
plt.scatter(mesh.x2,mesh.y2,10,mesh.zcoord[n])
#plt.hlines(np.mean(mesh.y2))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="864">

# %%
#basedir = '/mnt/lustre01/work/ab0995/a270088/DATA/swift.dkrz.de/'
basedir = '/work/ollie/orichter/'
meshpath  = basedir+'mesh/oce0_s/'
mesh = pf.fesom_mesh(meshpath, abg=[0,0,0], cavity='sigma')
lon_start = min(mesh.x2)
lat_start = np.mean(mesh.y2)
lon_end   = max(mesh.x2)
lat_end   = np.mean(mesh.y2)
#pf.plot_transect_map(lon_star
fl = Dataset(basedir+'/data/warm_sigma/RG47911.2021.oce.nc')
data = fl['temp'][-1]
# Out:
# Load 2d part of the grid in 0 second(s)
# Load 3d part of the grid in 0 seconds

# %%
npoints = 1000
data = fl.variables['temp'][-1,:]
fig, ax = plt.subplots(1,1, figsize=(15,7))
image = pf.plot_transect_sigma(data, mesh, 
                         lon_start,
                         lat_start,
                         lon_end,
                         lat_end,
                         npoints=npoints,
                         #levels = np.round(np.linspace(-2, 2, 42),2),
                         levels = np.linspace(min(data),max(data)),
                         #levels = np.linspace(-0.02,0.02),
                         cmap=cm.Spectral_r,
                         #cmap=cm.bwr,
                         maxdepth =6000,
                         title = 'Temperature for boundary restoring test (warm initial+cold forcing after 1 month)',
                         ncols=1,
                         figsize=(5,10),
                        ax = ax
                        )
cb = fig.colorbar(image, orientation='horizontal', ax=ax, pad=0.13)
cb.set_label('Potential Temperature in degC')
# Out:
# no cmocean

# %%
nodes,prof,dist = pf.plot_transect_sigma(data,mesh,lon_start,
                         lat_start,
                         lon_end,
                         lat_end,
                         npoints=1000,
                         #levels = np.round(np.linspace(-2, 2, 42),2),
                         levels = np.linspace(min(data),max(data)),
                         #levels = np.linspace(-0.02,0.02),
                         cmap=cm.Spectral_r,
                         #cmap=cm.bwr,
                         maxdepth =6000,
                         title = 'Temperature for boundary restoring test (warm initial+cold forcing after 1 month)',
                         ncols=1,
                         figsize=(5,10))

# %%
img = pf.plot_transect_sigma(data,mesh,lon_start,
                         lat_start,
                         lon_end,
                         lat_end,
                         npoints=1000,
                         #levels = np.round(np.linspace(-2, 2, 42),2),
                         levels = np.linspace(min(data),max(data)),
                         #levels = np.linspace(-0.02,0.02),
                         cmap=cm.Spectral_r,
                         #cmap=cm.bwr,
                         maxdepth =6000,
                         title = 'Temperature for boundary restoring test (warm initial+cold forcing after 1 month)',
                         ncols=1,
                         figsize=(5,10))
# Out:
# no cmocean

# %%
x1d = mesh.x2[np.unique(nodes)]
sort1d = np.argsort(x1d)
x1d = x1d[sort1d]
nodes32 = mesh.n32[np.unique(nodes)[sort1d]]
x2d = np.transpose(np.tile(x1d,(37,1)))
z2d = np.reshape(mesh.zcoord[nodes32.flatten()-1],x2d.shape)
data2d = np.reshape(data[nodes32.flatten()-1],x2d.shape)

# %%
# %matplotlib inline
plt.pcolormesh(x2d,-z2d,data2d)

# %%
plt.contourf(x2d,-z2d,data2d)

# %%
hape)

# %%
plt.plot(dist,depth)

# %%
x
# Out:
# array([ 0.80146922,  0.97100324,  0.83712004,  0.26698209,  1.91114133,
#         0.82533938, -1.00833697, -1.3684666 ,  0.79079409,  0.87982667,
#        -0.96902228, -0.63381287,  1.87504467,  0.77802839, -0.13446696,
#         0.81125078,  0.0471435 ,  1.71496548,  0.9590772 ,  0.48975613,
#         0.60618188, -0.41276955,  0.17295758,  1.19959811,  0.88617891,
#        -0.81854408, -1.35621648, -1.17549794, -1.46269845, -0.07757993,
#        -0.62991275, -0.54812284,  1.89167055, -1.55622555, -0.44694364,
#         1.1322635 ,  1.89158904, -0.06716158, -0.65431558,  0.26967614,
#        -1.80823396, -0.44425188,  1.62521458, -1.35592716,  0.97448454,
#         0.53189665, -0.70327993,  1.68950613, -1.05109425,  1.29578228,
#         1.00242856, -1.54486219,  1.38144498,  1.69572852, -1.11665283,
#         1.7322155 , -0.04400503, -0.10112544, -1.64333011, -1.08020729,
#         0.86374964, -0.01549535,  1.06595751,  1.58718929,  1.08889207,
# ...

# %%
import matplotlib
triangulation = matplotlib.tri.Triangulation(x,y)

# %%
nodes32 = mesh.n32[np.unique(nodes)-1]
# Out:
# array([ 0.80146922,  0.97100324,  0.83712004,  0.26698209,  1.91114133,
#         0.82533938, -1.00833697, -1.3684666 ,  0.79079409,  0.87982667,
#        -0.96902228, -0.63381287,  1.87504467,  0.77802839, -0.13446696,
#         0.81125078,  0.0471435 ,  1.71496548,  0.9590772 ,  0.48975613,
#         0.60618188, -0.41276955,  0.17295758,  1.19959811,  0.88617891,
#        -0.81854408, -1.35621648, -1.17549794, -1.46269845, -0.07757993,
#        -0.62991275, -0.54812284,  1.89167055, -1.55622555, -0.44694364,
#         1.1322635 ,  1.89158904, -0.06716158, -0.65431558,  0.26967614,
#        -1.80823396, -0.44425188,  1.62521458, -1.35592716,  0.97448454,
#         0.53189665, -0.70327993,  1.68950613, -1.05109425,  1.29578228,
#         1.00242856, -1.54486219,  1.38144498,  1.69572852, -1.11665283,
#         1.7322155 , -0.04400503, -0.10112544, -1.64333011, -1.08020729,
#         0.86374964, -0.01549535,  1.06595751,  1.58718929,  1.08889207,
# ...

# %%
triangulation = matplotlib.tri.Triangulation

# %%
npts = 100
x = np.random.uniform(-2, 2, npts)
y = np.random.uniform(-2, 2, npts)

# %%
#plt.tricontour(dist,depth,vals,levels=14)
plt.tricontour(triangulation)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-135-c738775f5295> in <module>()
#       1 #plt.tricontour(dist,depth,vals,levels=14)
# ----> 2 plt.tricontour(triangulation)
#
# /global/AWIsoft/intel/2018/intelpython2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in tricontour(*args, **kwargs)
#    3614                       mplDeprecation)
#    3615     try:
# -> 3616         ret = ax.tricontour(*args, **kwargs)
#    3617     finally:
#    3618         ax._hold = washold
#
# /global/AWIsoft/intel/2018/intelpython2/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in tricontour(self, *args, **kwargs)
#    7689
#    7690     def tricontour(self, *args, **kwargs):
# -> 7691         return mtri.tricontour(self, *args, **kwargs)
#    7692     tricontour.__doc__ = mtri.TriContourSet.tricontour_doc
#    7693
#
# ...

# %% [markdown]
# We just use closest points for selection, so on the map blues dots show generated transect, while red points are  model points that will be used for "interpolation" (we will just use nearest neighbor aproach).

# %% [markdown]
# Lets. now plot the transect from monthly data that we have extracted previously. There are plenty of parameters that you can control. Function `plot_transect` return instance of an image, so you can further modify it (font sizes and so on).

# %%
fl = Dataset(basedir+'/data/zero_forcing/RG47911.2021.oce.nc')
fl['temp'].shape
# Out:
# (29, 165962)

# %%
fl = Dataset(basedir+'/data/zero_forcing/RG47911.2021.oce.nc')
npoints = 1000
data = fl.variables['temp'][-1,:]-fl.variables['temp'][0,:]
fig, ax = plt.subplots(1,1, figsize=(15,7))
image = pf.plot_transect(data, mesh, 
                         lon_start,
                         lat_start,
                         lon_end,
                         lat_end,
                         npoints=npoints,
                         #levels = np.round(np.linspace(-2, 2, 42),2),
                         levels = np.linspace(min(data),max(data)),
                         #levels = np.linspace(-0.02,0.02),
                         cmap=cm.Spectral_r,
                         #cmap=cm.bwr,
                         maxdepth =6000,
                         title = 'ISOMIP zero_forcing temp diff',
                         ncols=1,
                         figsize=(5,10),
                        ax = ax
                        )
cb = fig.colorbar(image, orientation='horizontal', ax=ax, pad=0.13)
cb.set_label('degC')

# %%
[-1000.00,-100.00].astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-7a784676342c> in <module>()
# ----> 1 [-1000.00,-100.00].astype(int)
#
# AttributeError: 'list' object has no attribute 'astype'

# %%
def correct4cavity(data,nodes):
    ndep = np.shape(data)[1]
    nlen = np.shape(data)[0]
    data_tmp = np.ones((nlen,ndep*2))*-1000
    for i,node in enumerate(nodes):
        push_down = np.where(mesh.zlevs==mesh.zcoord[node])[0][0]
        data_tmp[i,push_down:push_down+ndep] = data[i]
    return data_tmp[:,:ndep]
trans_cav = correct4cavity(trans,nodes)

# %%
trans.data[1]
# Out:
# array([ 0.43611111,  0.51666667,  0.59722222,  0.67777778, -1.01388889,
#        -1.01388889, -1.01388889, -1.01388889, -1.01388889, -1.01388889,
#        -1.01388889, -1.01388889, -1.01388889, -1.01388889, -1.01388889,
#        -1.01388889, -1.01388889, -1.01388889, -1.01388889, -1.01388889,
#        -1.01388889, -1.01388889, -1.01388889, -1.01388889, -1.01388889,
#        -1.01388889, -1.01388889, -1.01388889, -1.01388889, -1.01388889,
#        -1.01388889, -1.01388889, -1.01388889, -1.01388889, -1.01388889,
#        -1.01388889, -1.01388889])

# %%
trans_cav[1]
# Out:
# array([ -1.00000000e+03,  -1.00000000e+03,  -1.00000000e+03,
#         -1.00000000e+03,  -1.00000000e+03,  -1.00000000e+03,
#         -1.00000000e+03,  -1.00000000e+03,  -1.00000000e+03,
#         -1.00000000e+03,  -1.00000000e+03,  -1.00000000e+03,
#         -1.00000000e+03,  -1.00000000e+03,  -1.00000000e+03,
#         -1.00000000e+03,  -1.00000000e+03,  -1.00000000e+03,
#         -1.00000000e+03,  -1.00000000e+03,  -1.00000000e+03,
#         -1.00000000e+03,  -1.00000000e+03,  -1.00000000e+03,
#         -1.00000000e+03,  -1.00000000e+03,  -1.00000000e+03,
#         -1.00000000e+03,  -1.00000000e+03,   4.36111111e-01,
#          5.16666667e-01,   5.97222222e-01,   6.77777778e-01,
#         -1.01388889e+00,  -1.01388889e+00,  -1.01388889e+00,
#         -1.01388889e+00])

# %%
maxdepth=6000
depth_index=(abs(mesh.zlevs-maxdepth)).argmin()
depth_index
# Out:
# 36

# %% [markdown]
# If instead of kilometers you would like to have lons or lats, below is the code that will help you to do so :) Pay attention to combination of `npoints`, `lonlat[7::8]` (were in this case `7` is a starting point and `8` is a step). The `1` in `lonlat[7::8][:,1]` is latitudes, to switch to longitudes change it to `0`. This crazy thing `$^{\circ}$S` adds $^{\circ}$S, change to `N`, `E` or `W`, depending on what you would like to show. I know now it look ubly, in the future will try to make it more automatic. On the other hand you have control on what exactly you are ploting :)

# %%
npoints = 80
lonlat = pf.transect_get_lonlat(lon_start, lat_start, lon_end, lat_end, npoints=npoints)
labeles = [str(abs(int(x)))+"$^{\circ}$S" for x in lonlat[7::8][:,1]]
labeles
# Out:
# ['65$^{\\circ}$S',
#  '60$^{\\circ}$S',
#  '55$^{\\circ}$S',
#  '50$^{\\circ}$S',
#  '45$^{\\circ}$S',
#  '40$^{\\circ}$S',
#  '35$^{\\circ}$S',
#  '30$^{\\circ}$S',
#  '25$^{\\circ}$S',
#  '20$^{\\circ}$S']

# %% [markdown]
# Let's use it:

# %%
npoints = 80
lonlat = pf.transect_get_lonlat(lon_start, lat_start, lon_end, lat_end, npoints=npoints)
labeles = [str(abs(int(x)))+"$^{\circ}$S" for x in lonlat[7::8][:,1]]
dist   = pf.transect_get_distance(lonlat) # get's distances between starting point and present point

fig, ax = plt.subplots(1,1, figsize=(15,7))
image = pf.plot_transect(data, mesh, 
                         lon_start,
                         lat_start,
                         lon_end,
                         lat_end,
                         npoints=npoints,
                         levels = np.round(np.linspace(-2, 13, 42),2),
                         cmap=cm.Spectral_r,
                         maxdepth =6000,
                         title = 'Southern Ocean Transect',
                         ncols=1,
                         figsize=(5,10),
                        ax = ax
                        )
cb = fig.colorbar(image, orientation='horizontal', ax=ax, pad=0.13)
cb.set_label('deg C')
ax.xaxis.set_ticks(dist[7::8])
ax.set_xticklabels(labeles, size=20);

# %% [markdown]
# ## Several transects at once

# %% [markdown]
# Let's get data for some other montsh, say April, July and October:

# %%
data1 = fl.variables['temp'][3,:]
data2 = fl.variables['temp'][6,:]
data3 = fl.variables['temp'][9,:]

# %% [markdown]
# Put all of them in to list:

# %%
data_all = [data, data1, data2, data3]

# %% [markdown]
# Now you can have several transects in a loop. Make sure you have changed number of rows (`nrows`), number of columns (`ncols`), `figsize` and other parameters at the top of the script :)

# %%
nrows = 2
ncols = 2
figsize = (15,10)
label = '$^{\circ}$C'
vmin = -2
vmax = 15
cmap = cm.Spectral_r
npoints = 100
cmap.set_bad(color = 'k', alpha = 1.)

lonlat = pf.transect_get_lonlat(lon_start, lat_start, lon_end, lat_end, npoints=npoints)
dist   = pf.transect_get_distance(lonlat)
labeles = [str(abs(int(x)))+"$^{\circ}$S" for x in lonlat[9::10][:,1]]

months = ['JAN', 'APR', 'JUL', 'NOV']
fig, ax = plt.subplots(nrows,ncols, figsize=figsize)
ax = ax.flatten()
# for i, sim in enumerate(data):
for i, sim in enumerate(data_all):   
    image = pf.plot_transect(sim, mesh, lon_start,
                      lat_start,
                      lon_end,
                      lat_end,
                      npoints=npoints,
                      levels = np.round(np.linspace(-3, 7, 41),2),
                      cmap=cmap,
                      maxdepth =6000,
                      label = '$^{\circ}$C',
                      title = months.pop(0),
                      ncols=3,
                      ax=ax[i])
    cb = fig.colorbar(image, orientation='horizontal', ax=ax[i], pad=0.16)
    cb.set_label(label)
    ax[i].xaxis.set_ticks(dist[9::10])
# ax.xaxis.set_ticks(list(range(lonlat.shape[0]))[9::10])
    ax[i].set_xticklabels(labeles, size=10)
    ax[i].set_xlabel(' ')
    ax[i].xaxis.grid(True)
